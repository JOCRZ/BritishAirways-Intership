# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://www.airlinequality.com/airline-reviews/british-airways/"

# %%
classes

first
business
p_economy
economy

# %%
page/{i}/?pagesize=10&filterby=

# %%
url = "https://www.airlinequality.com/airline-reviews/british-airways/page/1/?pagesize=10&filterby="
webpage = requests.get(url).text

# %%
soup = BeautifulSoup(webpage)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 9]>    <html class="no-js lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-GB">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    British Airways Customer Reviews - SKYTRAX
#   </title>
#   <!-- Google Chrome Frame for IE -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <!-- mobile meta -->
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="320" name="MobileOptimized"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport">
#    <!-- icons & favicons -->
# ...

# %%
for i in soup.findAll('h2',class_='text_header'):
    print(i.text.strip())
# Out:
# "British Airways was absolutely shocking"
# "service was mediocre at best"
# "BA standards continue to decline"
# "won the race to the bottom"
# "Not a reliable airline"
# "It is a national disgrace"
# "The worst journey in my life"
# "Very disappointed"
# "the service was shockingly bad"
# "Never again will I fly BA"

# %%
for i in soup.findAll('div',class_='text_content'):
    print(i.text.strip())
# Out:
# Not Verified |  Booked a very special holiday for me and my partner, September arrived and we were on our way to lovely South of France, Booked Business Class for us both to start the holiday right. As we were checking I was told the flight was over booked and our seats wouldn't print onto the ticket for some reason. We had already made sure the seats were booked when we had booked the flights nearly a year prior to going. Unfortunately when we arrived at the gate we were then told we would no longer be sat together and one of us would in fact have to go into economy. My girlfriend is an extremely nervous flyer and so had to take extra tablets to remain calm, She didn't have any food which we had pre booked also and she was sat right down the bottom end of the flight. We were held at the gate with another 4 or 5 couples all in the same predicament all due to the lovely money grabbing British Airways over booking the flight. They ended up refusing passengers in the end and even had pe
# ...

# %%
for i in soup.findAll('div',class_='rating-10'):
    print(i.text.strip())
# Out:
# 5/10
# 1/10
# 2/10
# 2/10
# 2/10
# 3/10
# 1/10
# 3/10
# 4/10
# 1/10
# 1/10

# %%
for i  in soup.findAll('h3',class_="text_sub_header userStatusWrapper"):
    print(i.text.strip())
# Out:
# Kane Kelly (United Kingdom) 5th October 2023
# Gary Storer (United Kingdom) 3rd October 2023
# A Jensen (United Kingdom) 2nd October 2023
# John Rockett (United Kingdom) 2nd October 2023
# Tatiana Bobrovskaya (United Kingdom) 2nd October 2023
# A Dawson (United Kingdom) 30th September 2023
# Massimo Garavaglia (Italy) 30th September 2023
# Tom Slowbe (United States) 28th September 2023
# E Anderson (United Kingdom) 28th September 2023
# 1 reviews
#
#
#
# C Horden (United Kingdom) 27th September 2023

# %%
content = soup.findAll('article',class_="comp comp_media-review-rated list-item media position-content review-873992")
len(content)
# Out:
# 0

# %%
date = []
rating = []
title = []
description = []

for i in range(10):
    date.append([i for i in soup.findAll('h3', class_='text_sub_header userStatusWrapper')][i].text.strip())
    rating.append([i for i in soup.findAll('div',class_='rating-10')][i].text.strip())
    title.append([i for i in soup.findAll('h2',class_='text_header')][i].text.strip())
    description.append([i for i in soup.findAll('div',class_='text_content')][i].text.strip())

dictionary = {'Date':date,'Rating':rating,'Title':title,'Description':description}
df = pd.DataFrame(dictionary)

# %%
df
# Out:
#                                                 Date Rating  \
# 0       Kane Kelly (United Kingdom) 5th October 2023   5/10
# 1      Gary Storer (United Kingdom) 3rd October 2023   1/10
# 2         A Jensen (United Kingdom) 2nd October 2023   2/10
# 3     John Rockett (United Kingdom) 2nd October 2023   2/10
# 4  Tatiana Bobrovskaya (United Kingdom) 2nd Octob...   2/10
# 5      A Dawson (United Kingdom) 30th September 2023   3/10
# 6     Massimo Garavaglia (Italy) 30th September 2023   1/10
# 7     Tom Slowbe (United States) 28th September 2023   3/10
# 8    E Anderson (United Kingdom) 28th September 2023   4/10
# 9  1 reviews\n\n\n\nC Horden (United Kingdom) 27t...   1/10
#
#                                        Title  \
# 0  "British Airways was absolutely shocking"
# 1             "service was mediocre at best"
# 2         "BA standards continue to decline"
# 3               "won the race to the bottom"
# 4                   "Not a reliable airline"
# ...

# %%
DataSet = pd.DataFrame()

for j in range (1,184):

    url = 'https://www.airlinequality.com/airline-reviews/british-airways/page/{}/?sortby=post_date%3ADesc&pagesize=20'.format(j)
    webpage = requests.get(url).text

    soup = BeautifulSoup(webpage)

    date = []
    rating = []
    title = []
    description = []

    for i in range(10):
        date.append([i for i in soup.findAll('h3', class_='text_sub_header userStatusWrapper')][i].text.strip())
        rating.append([i for i in soup.findAll('div',class_='rating-10')][i].text.strip())
        title.append([i for i in soup.findAll('h2',class_='text_header')][i].text.strip())
        description.append([i for i in soup.findAll('div',class_='text_content')][i].text.strip())

    dictionary = {'Date':date,'Rating':rating,'Title':title,'Description':description}
    df = pd.DataFrame(dictionary)

    DataSet = pd.concat([DataSet, df], ignore_index=True)

# %%
DataSet
# Out:
#                                                    Date Rating  \
# 0          Kane Kelly (United Kingdom) 5th October 2023   5/10
# 1         Gary Storer (United Kingdom) 3rd October 2023   1/10
# 2            A Jensen (United Kingdom) 2nd October 2023   2/10
# 3        John Rockett (United Kingdom) 2nd October 2023   2/10
# 4     Tatiana Bobrovskaya (United Kingdom) 2nd Octob...   2/10
# ...                                                 ...    ...
# 1825             C Thomas (United Kingdom) 6th May 2014   1/10
# 1826           Berry Nick (United Kingdom) 6th May 2014   6/10
# 1827             C Denson (United Kingdom) 5th May 2014   7/10
# 1828           A Hickling (United Kingdom) 4th May 2014  10/10
# 1829       Iain Henderson (United Kingdom) 3rd May 2014  10/10
#
#                                           Title  \
# 0     "British Airways was absolutely shocking"
# 1                "service was mediocre at best"
# 2            "BA standards continue to decline"
# ...

# %%
dataset = pd.read_csv('Extracted.csv')

# %%
df = dataset.copy()

# %%
df.Date
# Out:
# 0            Kane Kelly (United Kingdom) 5th October 2023
# 1           Gary Storer (United Kingdom) 3rd October 2023
# 2              A Jensen (United Kingdom) 2nd October 2023
# 3          John Rockett (United Kingdom) 2nd October 2023
# 4       Tatiana Bobrovskaya (United Kingdom) 2nd Octob...
#                               ...
# 1825               C Thomas (United Kingdom) 6th May 2014
# 1826             Berry Nick (United Kingdom) 6th May 2014
# 1827               C Denson (United Kingdom) 5th May 2014
# 1828             A Hickling (United Kingdom) 4th May 2014
# 1829         Iain Henderson (United Kingdom) 3rd May 2014
# Name: Date, Length: 1830, dtype: object

# %%
import re

# %%
import re

def date_extraction(string):
    date_pattern = r"\d{1,2}(\w{2})? [A-Za-z]+ \d{4}"
    matches = re.search(date_pattern, string)
    if matches:
        extracted_date = matches.group()
        return extracted_date

df['Date'] = df['Date'].apply(date_extraction)

# %%
df['Date'] = df['Date'].str.replace(r'(th|nd|rd|st)', '', regex=True)

# %%
from datetime import datetime

# %% [markdown]
# def date_convertion(string):
#     date_format = "%d %B %Y"
#     date = datetime.strptime(string,date_format)
#     return date
#
# df['Date'] = df['Date'].apply(date_convertion)

# %%
import traceback

try:
    df['Date'] = df['Date'].apply(date_convertion)
except Exception as e:
    # Print the error message and traceback
    print(f"An error occurred: {e}")
    traceback.print_exc()
# Out:
# An error occurred: name 'date_convertion' is not defined
# Traceback (most recent call last):
#   File "/tmp/ipykernel_2126/230308111.py", line 4, in <module>
#     df['Date'] = df['Date'].apply(date_convertion)
#                                   ^^^^^^^^^^^^^^^
# NameError: name 'date_convertion' is not defined

# %%
date_to_find = '25 Augu 2023'
result_df = df[df['Date'].str.contains(date_to_find, case=False, na=False)]
result_df
# Out:
#     Unnamed: 0          Date Rating              Title  \
# 20          20  25 Augu 2023   5/10  "Never again, BA"
#
#                                           Description
# 20  ✅ Trip Verified |  In June my flight was cance...

# %%
df['Date'] = df['Date'].str.replace('25 Augu 2023', '25 August 2023')

# %%
df.Date.unique()
# Out:
# array(['5 October 2023', '3 October 2023', '2 October 2023',
#        '30 September 2023', '28 September 2023', '27 September 2023',
#        '11 September 2023', '10 September 2023', '9 September 2023',
#        '6 September 2023', '4 September 2023', '2 September 2023',
#        '1 September 2023', '25 August 2023', '24 Augu 2023',
#        '19 Augu 2023', '13 Augu 2023', '12 Augu 2023', '11 Augu 2023',
#        '8 Augu 2023', '5 Augu 2023', '21 July 2023', '20 July 2023',
#        '18 July 2023', '17 July 2023', '16 July 2023', '9 July 2023',
#        '29 June 2023', '27 June 2023', '25 June 2023', '24 June 2023',
#        '23 June 2023', '22 June 2023', '8 June 2023', '7 June 2023',
#        '6 June 2023', '5 June 2023', '3 June 2023', '2 June 2023',
#        '1 June 2023', '17 May 2023', '14 May 2023', '13 May 2023',
#        '8 May 2023', '6 May 2023', '1 May 2023', '16 April 2023',
#        '15 April 2023', '14 April 2023', '13 April 2023', '12 April 2023',
# ...

# %%
df[['Day', 'Month', 'Year']] = df['Date'].str.split(' ', expand=True)

# %%
df.drop('Date', axis=1, inplace=True)

# %%
df.Month.unique()
# Out:
# array(['October', 'September', 'August', 'Augu', 'July', 'June', 'May',
#        'April', 'March', 'February', 'January', 'December', 'November'],
#       dtype=object)

# %%
def replace(string):
    if string == 'Augu':
        return 'August'
    else:
        return string

df['Month'] = df['Month'].apply(replace)

# %%
df['Date'] = pd.to_datetime(df['Year'].astype(str) + '-' + df['Month'] + '-' + df['Day'].astype(str))

# %%
df.drop(columns=['Day','Month','Year'],axis=1,inplace=True)

# %%
def convert_decimal(string):

    parts = string.split('/')
    if len(parts) == 2:
        numerator = float(parts[0])
        denominator = float(parts[1])
        
        decimal_value = numerator / denominator
        return float(decimal_value)
    

df['Rating'] = df['Rating'].apply(convert_decimal)

# %%
df['Title'] = df['Title'].str.replace('"', '')

# %%
split_df = df['Description'].str.split('|', n=1, expand=True)

df['Authentication'] = split_df[0]
df['text 1'] = split_df[1].fillna(df['Description'])

# %%
def replacing(string):
    
    if string == 'Not Verified':
        return string
    if string == '✅ Trip Verified ':
        return 'Verified'
    if string == '❎ Not Verified ':
        return 'Not Verified'
    if string == '✅ Verified Review ':
        return 'Verified'
    if string == '❎ Unverified ':
        return 'Verified'
    else:
        return None
    
df['Authentication'] = df['Authentication'].apply(replacing)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Rating', 'Title', 'Description', 'Date',
#        'Authentication', 'text 1'],
#       dtype='object')

# %%
df = df.drop(columns=['Unnamed: 0','Description'])

# %%
df['Description'] = df['Title'].str.cat(df['text 1'], sep=' ')

# %%
df.drop(columns=['text 1','Title'],axis=1,inplace=True)

# %%
df
# Out:
#       Rating       Date Authentication  \
# 0        0.5 2023-10-05           None
# 1        0.1 2023-10-03           None
# 2        0.2 2023-10-02       Verified
# 3        0.2 2023-10-02           None
# 4        0.2 2023-10-02       Verified
# ...      ...        ...            ...
# 1825     0.1 2014-05-06           None
# 1826     0.6 2014-05-06           None
# 1827     0.7 2014-05-05           None
# 1828     1.0 2014-05-04           None
# 1829     1.0 2014-05-03           None
#
#                                             Description
# 0     British Airways was absolutely shocking   Book...
# 1     service was mediocre at best  Just returned fr...
# 2     BA standards continue to decline   BA standard...
# 3     won the race to the bottom   Awful. Business c...
# 4     Not a reliable airline   Not a reliable airlin...
# ...                                                 ...
# 1825  British Airways customer review I'm not normal...
# ...

# %%
df = df[['Date', 'Authentication', 'Description', 'Rating']]
